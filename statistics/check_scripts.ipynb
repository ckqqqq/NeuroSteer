# %%
import numpy as np
import os
os.listdir(".//")
# Out:
# ['qwen2.5-3_truthful_qa_judge_acc_probes_fold_1.npy',
#  'check_scripts.ipynb',
#  'qwen2.5-3_truthful_qa_judge_acc_probes_fold_0.npy']

# %%
data=np.load('qwen2.5-3_truthful_qa_judge_acc_probes_fold_1.npy')

# %%
data.sort()

# %%
data=data-0.5

# %%
data.shape
# Out:
# (36, 16)

# %%
data.flatten()
# Out:
# array([0.05183946, 0.05351171, 0.05518395, 0.05518395, 0.05685619,
#        0.05685619, 0.05852843, 0.06020067, 0.06354515, 0.06354515,
#        0.06354515, 0.06521739, 0.07023411, 0.07525084, 0.07859532,
#        0.07859532, 0.07190635, 0.07859532, 0.0819398 , 0.0819398 ,
#        0.08528428, 0.08695652, 0.09197324, 0.09364548, 0.09364548,
#        0.09364548, 0.10033445, 0.10200669, 0.10367893, 0.10535117,
#        0.11036789, 0.13043478, 0.08026756, 0.08026756, 0.0819398 ,
#        0.08361204, 0.08528428, 0.08695652, 0.08862876, 0.09197324,
#        0.09197324, 0.09197324, 0.09698997, 0.10033445, 0.10367893,
#        0.10367893, 0.11036789, 0.11705686, 0.09531773, 0.09531773,
#        0.10033445, 0.10033445, 0.10200669, 0.10367893, 0.10367893,
#        0.10367893, 0.10702341, 0.10702341, 0.10702341, 0.10869565,
#        0.11036789, 0.11204013, 0.11538462, 0.1270903 , 0.06856187,
#        0.07859532, 0.08528428, 0.09197324, 0.09364548, 0.09531773,
# ...

# %%
import pandas
pandas.DataFrame(data.flatten()).describe()
# Out:
#                 0
# count  576.000000
# mean     0.206075
# std      0.075239
# min      0.051839
# 25%      0.135452
# 50%      0.214883
# 75%      0.272575
# max      0.332776
